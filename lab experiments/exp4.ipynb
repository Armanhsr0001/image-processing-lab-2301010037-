# %% [markdown]
# <a href="https://colab.research.google.com/github/Armanhsr0001/image-processing-lab-2301010037-/blob/main/exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
import io
from PIL import Image

# %%
uploaded= files.upload

# %%
img=cv2.imread('/content/noisy.ppm.png',0)

# %%
f = np.fft.fft2(img)

# %%
fshift=np.fft.fftshift(f)

# %%
row,cols=img.shape

# %%
crow,ccol=row//2,cols//2

# %%
mask_lp=np.zeros((row,cols),np.uint8)

# %%
mask_lp[crow-5:crow+5,ccol-5:ccol+5]=1

# %%
lp=np.fft.ifft2(np.fft.ifftshift(fshift*mask_lp))

# %%
cv2.imwrite("lpf_noisy.ppm.png",np.abs(lp))
# Out:
# True

# %%
from google.colab import files

# %%
files.download("lpf_noisy.ppm.png")

# %%
mask_hp=1-mask_lp

# %%
hp=np.fft.ifft2(np.fft.ifftshift(fshift*mask_hp))

# %%
cv2.imwrite('hpf_noisy.ppm.png',np.abs(hp))
# Out:
# True

# %%
from google.colab import files

# %%
files.download("lpf_noisy.ppm.png")

# %%
mask_hp=1-mask_lp

# %%
hp=np.fft.ifft2(np.fft.ifftshift(fshift*mask_hp))

# %%
cv2.imwrite('hpf_noisy.ppm.png',np.abs(hp))
# Out:
# True

# %%
files.download('hpf_noisy.ppm.png')
